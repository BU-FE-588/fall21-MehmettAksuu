# %%
### Task 1

class course:
    def __init__(self,code,name,credit_info):
        self.code = code
        self.name = name
        self.credit_info = credit_info

my_course = course('FE588', 'Python Programming for Financial Engineering',3)

print('Course code is:',my_course.code)
print('Course name is:',my_course.name)
print('Course credit is:',my_course.credit_info)
# Out:
# Course code is: FE588
# Course name is: Python Programming for Financial Engineering
# Course credit is: 3

# %%
### Task 2

class student:
    def __init__(self,name,id,grades):
        self.name = name
        self.id = id
        self.grades = grades

mustafa = student('Mustafa', 123, grades=[85, 70, 100])

print('Student name is:',mustafa.name)
print('Student ID is:',mustafa.id)
print('Student grades are:',mustafa.grades)
# Out:
# Student name is: Mustafa
# Student ID is: 123
# Student grades are: [85, 70, 100]

# %%
### Task 3

class course:
    def __init__(self,code,name,credit_info,students):
        self.code = code
        self.name = name
        self.credit_info = credit_info
        self.students = students
        

Yusuf = student('Yusuf', 123, grades=None)
Ahmet = student('Ahmet', 124, grades=[90, 95, 87])


my_course = course('FE588', 'Python Programming for Financial Engineering',3, students=[Yusuf, Ahmet])

print('Course code is:',my_course.code)
print('Course name is:',my_course.name)
print('Course credit is:',my_course.credit_info)

class student:
    def __init__(self,name,id,grades):
        self.name = name
        self.id = id
        self.grades = grades




for student in my_course.students:
    print('***************')
    print('***************')
    print('Student name is:',student.name)
    print('Student ID is:', student.id)
    print('Student grades are:',student.grades)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-dc45d6fbb2fd> in <module>
#       9
#      10
# ---> 11 Yusuf = student('Yusuf', 123, grades=None)
#      12 Ahmet = student('Ahmet', 124, grades=[90, 95, 87])
#      13
#
# TypeError: 'student' object is not callable

# %%
class course:
    def __init__(self,code,name,credit_info,students):
        self.code = code
        self.name = name
        self.credit_info = credit_info
        self.students = students
    
    def add(self,student):
        self.students.append(student)


my_course = course('FE588', 'Python Programming for Financial Engineering',3, students=[Yusuf, Ahmet])

print('Course code is:',my_course.code)
print('Course name is:',my_course.name)
print('Course credit is:',my_course.credit_info)

class student:
    def __init__(self,name,id,grades):
        self.name = name
        self.id = id
        self.grades = grades


Yusuf = student('Yusuf', 123, grades=None)
Ahmet = student('Ahmet', 124, grades=[90, 95, 87])

Mehmet = student('Mehmet',125, grades=[100,100,100])
my_course.add(student=Mehmet)


for student in my_course.students:
    print('***************')
    print('***************')
    print('Student name is:',student.name)
    print('Student ID is:',student.id)
    print('Student grades are:',student.grades)
# Out:
# Course code is: FE588
# Course name is: Python Programming for Financial Engineering
# Course credit is: 3
# ***************
# ***************
# Student Name is: Yusuf
# Student ID is: 123
# Student Grades are: None
# ***************
# ***************
# Student Name is: Ahmet
# Student ID is: 124
# Student Grades are: [90, 95, 87]
# ***************
# ***************
# Student Name is: Mehmet
# Student ID is: 125
# Student Grades are: [100, 100, 100]

# %%
### Task 4

class course:
    def __init__(self,code,name,credit_info,students):
        self.code = code
        self.name = name
        self.credit_info = credit_info
        self.students = students
        
    def average(self,student):
        if type(student.grades) == list:
            return sum(student.grades)/len(student.grades)
        else:
            return 'There is no grade..'




class student:
    def __init__(self,name,id,grades):
        self.name = name
        self.id = id
        self.grades = grades


Yusuf = student('Yusuf', 123, grades=None)
Ahmet = student('Ahmet', 124, grades=[90, 95, 87])
Mehmet = student('Mehmet', 124, grades=[100, 92, 70])

my_course = course('FE588', 'Python Programming for Financial Engineering',3, students=[Yusuf, Ahmet,Mehmet])



   

print('Average grade of Yusuf is:',my_course.average(Yusuf))
print('Average grade of Ahmet is:',my_course.average(Ahmet))
print('Average grade of Mehmet is:',my_course.average(Mehmet))
# Out:
# Average grade of Yusuf is: There is no grade..
# Average grade of Ahmet is: 90.66666666666667
# Average grade of Mehmet is: 87.33333333333333

# %%
### Task 5

class course:
    def __init__(self,code,name,credit_info,students):
        self.code = code
        self.name = name
        self.credit_info = credit_info
        self.students = students
        
    def average(self,student):
        if type(student.grades) == list:
            return sum(student.grades)/len(student.grades)
        else:
            return 'There is no grade..'
        
    def max_avg(self):
            max=(self.students[0],sum(self.students[0].grades)/len(self.students[0].grades)if (self.students[0].grades) else 0)
            for student in self.students[1:]:
                avg=sum(student.grades)/len(student.grades)if (student.grades) else 0 
                if avg>max[1]:
                    max=(student,avg)
            print(f'THe best student is {max[0].name} with the average grades of {max[1] :.2f}')        

        
class student:
    def __init__(self,name,id,grades):
        self.name = name
        self.id = id
        self.grades = grades
        
Yusuf = student('Yusuf', 123, grades=None)
Ahmet = student('Ahmet', 124, grades=[90, 95, 87])
Mehmet = student('Mehmet', 124, grades=[100, 92, 96])
        
my_course = course('FE588', 'Python Programming for Financial Engineering',3, students=[Yusuf, Ahmet,Mehmet])

my_course.max_avg()
# Out:
# THe best student is Mehmet with the average grades of 96.00

# %%
### Task 6

from matplotlib import image
from matplotlib import pyplot
from numpy import asarray

image = image.imread('/Users/mehmetaksu/Documents/aksu.jpg')
data = asarray(image)

pyplot.imshow(image)
pyplot.show()
print(type(image))
image.shape
# Out:
# <class 'numpy.ndarray'>
# (512, 512, 3)

# %%
### Task 7

a = image[0:,0:,0]
plt.imshow(a)

# %%
b = image[0:,0:,1]
plt.imshow(b)

# %%
c = image[0:,0:,2]
plt.imshow(c)

# %%
### Task 8

average_a = a.mean(axis=0)
max_a = a.max(axis=0)
min_a = a.min(axis=0)

average_b = b.mean(axis=0)
max_b = b.max(axis=0)
min_b = b.min(axis=0)

average_c = c.mean(axis=0)
max_c = c.max(axis=0)
min_c = c.min(axis=0)
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
### Task 9

plt.imshow(image[:,:256])

# %%
plt.imshow(image[:,256:])

# %%
d = image[:,:256]-image[:,256:]
plt.imshow(d)

# %%
### Task 10-11

e = 5
f = 2
g = 10
h = 1
j = 7
k = 2
N1 = np.random.normal (e, f, image.shape)
N2 = np.random.normal (g, h, image.shape)
N3 = np.random.normal (j, k, image.shape)
N4 = N1 + N2
N5 = N1 + N3
N6 = N2 + N3

image = image.astype(type(N4))
image = image + N4
image = image.astype('uint8')
pyplot.imshow(image.astype('uint8'))

# %%
image = image.astype(type(N5))
image = image + N5
image = image.astype('uint8')
pyplot.imshow(image.astype('uint8'))

# %%
image = image.astype(type(N6))
image = image + N6
image = image.astype('uint8')
pyplot.imshow(image.astype('uint8'))
